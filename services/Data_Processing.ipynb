# %%
import pandas as pd

# %%
original_data = pd.read_csv('original_data.csv')
original_data
# Out:
#        Unnamed: 0   User_ID  Gender  Age  Height  Weight  Duration  \
# 0               0  14733363    male   68   190.0    94.0      29.0
# 1               1  14861698  female   20   166.0    60.0      14.0
# 2               2  11179863    male   69   179.0    79.0       5.0
# 3               3  16180408  female   34   179.0    71.0      13.0
# 4               4  17771927  female   27   154.0    58.0      10.0
# ...           ...       ...     ...  ...     ...     ...       ...
# 14995       14995  15644082  female   20   193.0    86.0      11.0
# 14996       14996  17212577  female   27   165.0    65.0       6.0
# 14997       14997  17271188  female   43   159.0    58.0      16.0
# 14998       14998  18643037    male   78   193.0    97.0       2.0
# 14999       14999  11751526    male   63   173.0    79.0      18.0
#
#        Heart_Rate  Body_Temp  Calories  ... HeadCircumference  ShoulderWidth  \
# 0           105.0       40.8     231.0  ...             55.88          45.72
# ...

# %%
print(original_data.columns.tolist())
# Out:
# ['Unnamed: 0', 'User_ID', 'Gender', 'Age', 'Height', 'Weight', 'Duration', 'Heart_Rate', 'Body_Temp', 'Calories', 'Exercise_type_raw', 'HeadCircumference', 'ShoulderWidth', 'ChestWidth', 'Belly', 'Waist', 'Hips', 'ArmLength', 'ShoulderToWaist', 'WaistToKnee', 'LegLength']

# %%
prepared_data = original_data.drop(original_data.columns[0], axis=1)

# %%
prepared_data.drop(['User_ID', 'Body_Temp', 'HeadCircumference', 'ShoulderWidth', 'ChestWidth', 'Belly', 'Waist', 'Hips', 'ArmLength', 'ShoulderToWaist', 'WaistToKnee', 'LegLength'], axis=1, inplace=True)

# %%
prepared_data['Height'] = prepared_data['Height'].astype(int)
prepared_data['Weight'] = prepared_data['Weight'].astype(int)
prepared_data['Heart_Rate'] = prepared_data['Heart_Rate'].astype(int)
prepared_data['Duration'] = prepared_data['Duration'].astype(int)
prepared_data['Calories'] = prepared_data['Calories'].astype(int)
prepared_data
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Calories  \
# 0        male   68     190      94        29         105       231
# 1      female   20     166      60        14          94        66
# 2        male   69     179      79         5          88        26
# 3      female   34     179      71        13         100        71
# 4      female   27     154      58        10          81        35
# ...       ...  ...     ...     ...       ...         ...       ...
# 14995  female   20     193      86        11          92        45
# 14996  female   27     165      65         6          85        23
# 14997  female   43     159      58        16          90        75
# 14998    male   78     193      97         2          84        11
# 14999    male   63     173      79        18          92        98
#
#                            Exercise_type_raw
# 0      Cycling, 16-19 mph, very fast, racing
# 1                  Stationary cycling, light
# ...

# %%
prepared_data.rename(columns={'Exercise_type_raw': 'ExerciseNameENG', 'Heart_Rate': 'HeartRate'}, inplace=True)
prepared_data['GenderCode'] = ''
prepared_data['ExerciseNameUKR'] = ''
prepared_data['ExerciseID'] = ''
prepared_data
# Out:
#        Gender  Age  Height  Weight  Duration  HeartRate  Calories  \
# 0        male   68     190      94        29        105       231
# 1      female   20     166      60        14         94        66
# 2        male   69     179      79         5         88        26
# 3      female   34     179      71        13        100        71
# 4      female   27     154      58        10         81        35
# ...       ...  ...     ...     ...       ...        ...       ...
# 14995  female   20     193      86        11         92        45
# 14996  female   27     165      65         6         85        23
# 14997  female   43     159      58        16         90        75
# 14998    male   78     193      97         2         84        11
# 14999    male   63     173      79        18         92        98
#
#                              ExerciseNameENG GenderCode ExerciseNameUKR  \
# 0      Cycling, 16-19 mph, very fast, racing
# 1                  Stationary cycling, light
# ...

# %%
exercise_names = prepared_data['ExerciseNameENG'].unique()
print('Amount of exercises:', len(exercise_names))
print('List of exercises:', exercise_names.tolist())
# Out:
# Amount of exercises: 33
# ...

# %%
prepared_data.loc[prepared_data['ExerciseNameENG'] == '


prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Stationary cycling, very light', 'ExerciseID'] = '23'
prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Stationary cycling, very light', 'ExerciseNameUKR'] = 'Стаціонарний велоспорт, дуже легкий режим'

prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Stationary cycling, light', 'ExerciseID'] = '24'
prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Stationary cycling, light', 'ExerciseNameUKR'] = 'Стаціонарний велоспорт, легкий режим'

prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Stationary cycling, moderate', 'ExerciseID'] = '25'
prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Stationary cycling, moderate', 'ExerciseNameUKR'] = 'Стаціонарний велоспорт, помірний режим'

prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Stationary cycling, vigorous', 'ExerciseID'] = '26'
prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Stationary cycling, vigorous', 'ExerciseNameUKR'] = 'Стаціонарний велоспорт, швидкий'

prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Stationary cycling, very vigorous', 'ExerciseID'] = '27'
prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Stationary cycling, very vigorous', 'ExerciseNameUKR'] = 'Стаціонарний велоспорт, дуже швидкий режим'

prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Standing, playing with children, light', 'ExerciseID'] = '28'
prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Standing, playing with children, light', 'ExerciseNameUKR'] = 'Стояння, легка гра з дітьми'

prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Stair machine', 'ExerciseID'] = '29'
prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Stair machine', 'ExerciseNameUKR'] = 'Тренажер-сходинки'

prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Walking, under 2.0 mph, very slow', 'ExerciseID'] = '30'
prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Walking, under 2.0 mph, very slow', 'ExerciseNameUKR'] = 'Ходьба, <5 км/год, повільний темп'

prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Walking 3.0 mph, moderate', 'ExerciseID'] = '31'
prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Walking 3.0 mph, moderate', 'ExerciseNameUKR'] = 'Ходьба, 5 км/год, помірний темп'

prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Walking 3.5 mph, brisk pace', 'ExerciseID'] = '32'
prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Walking 3.5 mph, brisk pace', 'ExerciseNameUKR'] = 'Ходьба, 6 км/год, швидкий темп'

prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Walking 4.5 mph', 'ExerciseID'] = '33'
prepared_data.loc[prepared_data['ExerciseNameENG'] == 'Walking 4.5 mph', 'ExerciseNameUKR'] = 'Ходьба, 7 км/год, дуже швидкий темп'

# %%
prepared_data.loc[prepared_data['Gender'] == 'male', 'GenderCode'] = '0'
prepared_data.loc[prepared_data['Gender'] == 'female', 'GenderCode'] = '1'

# %%
prepared_data = prepared_data[['Gender', 'GenderCode', 'Age', 'Height', 'Weight', 'HeartRate', 'ExerciseNameENG', 'ExerciseNameUKR', 'ExerciseID', 'Duration', 'Calories']]
prepared_data
# Out:
#        Gender GenderCode  Age  Height  Weight  HeartRate  \
# 0        male          0   68     190      94        105
# 1      female          1   20     166      60         94
# 2        male          0   69     179      79         88
# 3      female          1   34     179      71        100
# 4      female          1   27     154      58         81
# ...       ...        ...  ...     ...     ...        ...
# 14995  female          1   20     193      86         92
# 14996  female          1   27     165      65         85
# 14997  female          1   43     159      58         90
# 14998    male          0   78     193      97         84
# 14999    male          0   63     173      79         92
#
#                              ExerciseNameENG  \
# 0      Cycling, 16-19 mph, very fast, racing
# 1                  Stationary cycling, light
# 2                    Watering lawn or garden
# 3                                 Unicycling
# 4             Stationary cycling, very light
# ...

# %%
prepared_data.to_csv('data_processed.csv', index=False)
test_data_processed = pd.read_csv('data_processed.csv')
test_data_processed
# Out:
#        Gender  GenderCode  Age  Height  Weight  HeartRate  \
# 0        male           0   68     190      94        105
# 1      female           1   20     166      60         94
# 2        male           0   69     179      79         88
# 3      female           1   34     179      71        100
# 4      female           1   27     154      58         81
# ...       ...         ...  ...     ...     ...        ...
# 14995  female           1   20     193      86         92
# 14996  female           1   27     165      65         85
# 14997  female           1   43     159      58         90
# 14998    male           0   78     193      97         84
# 14999    male           0   63     173      79         92
#
#                              ExerciseNameENG  \
# 0      Cycling, 16-19 mph, very fast, racing
# 1                  Stationary cycling, light
# 2                    Watering lawn or garden
# 3                                 Unicycling
# ...
